# %% [markdown]
# Source [Link](https://makersportal.com/blog/2018/8/16/rotating-globe-in-python-using-basemap-toolkit)

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np

# %%
m = Basemap(width=12000000, height=9000000, projection="lcc", resolution=None, 
            lat_1=45., lat_2=25, lat_0=0, lon_0=0.)
m.bluemarble()
